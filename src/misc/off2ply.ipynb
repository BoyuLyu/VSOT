# %%
import pymeshlab
import os
filepath = '/work/boyu/EM_astrocyte/materials_for_paper_VSOT/VSOT_data_paired_with_codes/data/performance_testing_level_2_segmentation/large_dataset_3_annotator_L2345_w_stubby/gt_final_800/uniformly_selected_samples/off_file'
files = [f for f in os.listdir(filepath) if f.endswith('.off')]
# Out:
# ...
# Unable to load the following plugins:
#
# 	libio_e57.so: libio_e57.so does not seem to be a Qt Plugin.
#
# Cannot load library /home/boyu/anaconda3/envs/py3_torch/lib/python3.8/site-packages/pymeshlab/lib/plugins/libio_e57.so: (/lib/x86_64-linux-gnu/libp11-kit.so.0: undefined symbol: ffi_type_pointer, version LIBFFI_BASE_7.0)

# %%
for file in files:
    ms = pymeshlab.MeshSet()
    ms.load_new_mesh(os.path.join(filepath, file))

    ms.save_current_mesh(os.path.join(filepath, (os.path.splitext(file)[0])+'.ply'))
    print(file)
# Out:
# 13_022_8_14.off
# 23_414_17_5.off
# 20_138_170.off
# 21_157_105.off
# 13_202_2_31.off
# 25_225_154.off
# 11_014_2_7.off
# 11_420_8_2.off
# 19_123_33.off
# 11_133_3_13.off
# 23_211_7_3.off
# 19_127_147.off
# 12_314_9_4.off
# 28_299_92.off
# 23_444_10_3.off
# 28_295_22.off
# 26_256_139.off
# 13_132_3_20.off
# 27_270_210.off
# 21_162_16.off
# 12_013_7_3.off
# 28_304_50.off
# 11_232_7_6.off
# 24_032_16_9.off
# 11_303_23_19.off
# 13_222_7_5.off
# 30_323_9.off
# 25_226_66.off
# 28_305_30.off
# 11_020_20_11.off
# 11_320_13_13.off
# 11_114_2_4.off
# 23_032_5_4.off
# 33_354_55.off
# 12_314_9_3.off
# 13_032_8_7.off
# 19_125_60.off
# 13_012_4_19.off
# 23_220_5_4.off
# 27_268_67.off
# 11_021_1_4.off
# 26_252_68.off
# 21_161_127.off
# 27_272_67.off
# 27_262_52.off
# 26_249_173.off
# 13_022_8_4.off
# 13_212_2_6.off
# 11_100_19_13.off
# 12_224_4_2.off
# 22_174_81.off
# 25_224_185.off
# 11_221_11_2.off
# 13_031_8_7.off
# 19_123_5.off
# 19_127_11.off
# 28_296_8.off
# 27_265_141.off
# 12_220_16_1.off
# ...
